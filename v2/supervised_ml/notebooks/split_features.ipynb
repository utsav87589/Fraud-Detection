# %% [markdown]
# ## Split features : categorical and numerical columns

# %%
### autoreloader
# %load_ext autoreload
# %autoreload 2

# %%
### setting up the path
import sys
sys.path.append('../')

# %%
from src.data.load_data import load_data, get_info, get_nan_duplicates_shape, get_shape, get_unique, get_value_counts, save_data, drop_col
from src.processing.split_features import split_feature

# %%
### setting up the data path
train_path = '../data/split/train.csv'
valid_path = '../data/split/valid.csv'

# %% [markdown]
# ##### *************** Train data *****************

# %%
### loading up and veryfying the train data
df_train = load_data(train_path)
df_train.head()
# Out:
#    Transaction_Amount Transaction_Type            Timestamp  Account_Balance  \
# 0               80.39   ATM Withdrawal  2023-04-13 16:02:00         32068.28
# 1              196.60    Bank Transfer  2023-03-27 05:02:00         94961.81
# 2               21.88   ATM Withdrawal  2023-09-27 23:30:00         39354.55
# 3              121.23           Online  2023-09-10 13:13:00         46138.99
# 4               34.53           Online  2023-01-13 06:58:00         52750.58
#
#   Device_Type  Location Merchant_Category  IP_Address_Flag  \
# 0      Tablet    London            Travel                0
# 1      Mobile  New York       Electronics                0
# 2      Tablet    Sydney       Electronics                0
# 3      Mobile    London            Travel                0
# 4      Mobile    Sydney         Groceries                0
#
#    Previous_Fraudulent_Activity  Daily_Transaction_Count  \
# 0                             0                        5
# ...

# %%
### veryfying the shape
get_shape(df_train)
# Out:
# (40000, 19)

# %%
### veryfying the nan values
get_nan_duplicates_shape(df_train)
# Out:
# shape : (40000, 19)
# duplicate values : 0
# Transaction_Amount              0
# Transaction_Type                0
# Timestamp                       0
# Account_Balance                 0
# Device_Type                     0
# Location                        0
# Merchant_Category               0
# IP_Address_Flag                 0
# Previous_Fraudulent_Activity    0
# Daily_Transaction_Count         0
# Avg_Transaction_Amount_7d       0
# Failed_Transaction_Count_7d     0
# Card_Type                       0
# Card_Age                        0
# Transaction_Distance            0
# Authentication_Method           0
# Risk_Score                      0
# Is_Weekend                      0
# Fraud_Label                     0
# dtype: int64

# %%
### get info
get_info(df_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Transaction_Amount            40000 non-null  float64
#  1   Transaction_Type              40000 non-null  object
#  2   Timestamp                     40000 non-null  object
#  3   Account_Balance               40000 non-null  float64
#  4   Device_Type                   40000 non-null  object
#  5   Location                      40000 non-null  object
#  6   Merchant_Category             40000 non-null  object
#  7   IP_Address_Flag               40000 non-null  int64
#  8   Previous_Fraudulent_Activity  40000 non-null  int64
#  9   Daily_Transaction_Count       40000 non-null  int64
#  10  Avg_Transaction_Amount_7d     40000 non-null  float64
#  11  Failed_Transaction_Count_7d   40000 non-null  int64
# ...

# %%
### splitting the categorical and numerical columns
cat_cols_train, num_cols_train = split_feature(df_train, force_num = ['Timestamp'])

# %%
### veryfying the split
cat_cols_train.head()
# Out:
#   Transaction_Type Device_Type  Location Merchant_Category   Card_Type  \
# 0   ATM Withdrawal      Tablet    London            Travel  Mastercard
# 1    Bank Transfer      Mobile  New York       Electronics        Visa
# 2   ATM Withdrawal      Tablet    Sydney       Electronics  Mastercard
# 3           Online      Mobile    London            Travel    Discover
# 4           Online      Mobile    Sydney         Groceries        Amex
#
#   Authentication_Method
# 0                   PIN
# 1                   OTP
# 2                   OTP
# 3                   PIN
# 4              Password

# %%
### get shape
get_shape(cat_cols_train)
# Out:
# (40000, 6)

# %%
### veryfying the numerical column split
num_cols_train.head()
# Out:
#    Transaction_Amount  Account_Balance  IP_Address_Flag  \
# 0               80.39         32068.28                0
# 1              196.60         94961.81                0
# 2               21.88         39354.55                0
# 3              121.23         46138.99                0
# 4               34.53         52750.58                0
#
#    Previous_Fraudulent_Activity  Daily_Transaction_Count  \
# 0                             0                        5
# 1                             0                        8
# 2                             0                        7
# 3                             0                        8
# 4                             0                        6
#
#    Avg_Transaction_Amount_7d  Failed_Transaction_Count_7d  Card_Age  \
# 0                     112.75                            4       142
# 1                     199.95                            1        32
# 2                     234.75                            2       203
# ...

# %%
### get shape
get_shape(num_cols_train)
# Out:
# (40000, 13)

# %% [markdown]
# ##### *************** Valid data *****************

# %%
### loading the data
df_valid = load_data(valid_path)
df_valid.head()
# Out:
#    Transaction_Amount Transaction_Type            Timestamp  Account_Balance  \
# 0               19.98           Online  2023-02-10 02:49:00          1804.81
# 1               45.32    Bank Transfer  2023-03-26 22:32:00         46648.03
# 2               32.25   ATM Withdrawal  2023-08-05 12:29:00         80244.56
# 3               35.41              POS  2023-01-22 19:26:00         24611.99
# 4               57.80    Bank Transfer  2023-08-20 12:11:00         27154.09
#
#   Device_Type  Location Merchant_Category  IP_Address_Flag  \
# 0      Mobile    Sydney          Clothing                0
# 1      Mobile  New York            Travel                0
# 2      Laptop     Tokyo       Restaurants                0
# 3      Tablet    Mumbai            Travel                0
# 4      Tablet    Sydney         Groceries                1
#
#    Previous_Fraudulent_Activity  Daily_Transaction_Count  \
# 0                             0                        2
# ...

# %%
### checking the shape
get_shape(df_valid)
# Out:
# (10000, 18)

# %%
### veryfying the nan
get_nan_duplicates_shape(df_valid)
# Out:
# shape : (10000, 18)
# duplicate values : 0
# Transaction_Amount              0
# Transaction_Type                0
# Timestamp                       0
# Account_Balance                 0
# Device_Type                     0
# Location                        0
# Merchant_Category               0
# IP_Address_Flag                 0
# Previous_Fraudulent_Activity    0
# Daily_Transaction_Count         0
# Avg_Transaction_Amount_7d       0
# Failed_Transaction_Count_7d     0
# Card_Type                       0
# Card_Age                        0
# Transaction_Distance            0
# Authentication_Method           0
# Risk_Score                      0
# Is_Weekend                      0
# dtype: int64

# %%
### veryfying the info
get_info(df_valid)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Transaction_Amount            10000 non-null  float64
#  1   Transaction_Type              10000 non-null  object
#  2   Timestamp                     10000 non-null  object
#  3   Account_Balance               10000 non-null  float64
#  4   Device_Type                   10000 non-null  object
#  5   Location                      10000 non-null  object
#  6   Merchant_Category             10000 non-null  object
#  7   IP_Address_Flag               10000 non-null  int64
#  8   Previous_Fraudulent_Activity  10000 non-null  int64
#  9   Daily_Transaction_Count       10000 non-null  int64
#  10  Avg_Transaction_Amount_7d     10000 non-null  float64
#  11  Failed_Transaction_Count_7d   10000 non-null  int64
# ...

# %%
### making the split
cat_cols_valid, num_cols_valid = split_feature(df_valid, force_num = ['Timestamp'])

# %%
### veryfying the both
cat_cols_valid.head()
# Out:
#   Transaction_Type Device_Type  Location Merchant_Category   Card_Type  \
# 0           Online      Mobile    Sydney          Clothing  Mastercard
# 1    Bank Transfer      Mobile  New York            Travel        Amex
# 2   ATM Withdrawal      Laptop     Tokyo       Restaurants        Amex
# 3              POS      Tablet    Mumbai            Travel  Mastercard
# 4    Bank Transfer      Tablet    Sydney         Groceries        Visa
#
#   Authentication_Method
# 0                   OTP
# 1              Password
# 2              Password
# 3                   OTP
# 4             Biometric

# %%
### veryfying the shape
get_shape(cat_cols_valid)
# Out:
# (10000, 6)

# %%
### num_cols_valid
num_cols_valid.head()
# Out:
#    Transaction_Amount  Account_Balance  IP_Address_Flag  \
# 0               19.98          1804.81                0
# 1               45.32         46648.03                0
# 2               32.25         80244.56                0
# 3               35.41         24611.99                0
# 4               57.80         27154.09                1
#
#    Previous_Fraudulent_Activity  Daily_Transaction_Count  \
# 0                             0                        2
# 1                             1                       11
# 2                             0                        7
# 3                             0                        3
# 4                             0                        1
#
#    Avg_Transaction_Amount_7d  Failed_Transaction_Count_7d  Card_Age  \
# 0                     350.41                            3       214
# 1                      47.14                            1        78
# 2                     160.14                            2        59
# ...

# %%
### get shape
get_shape(num_cols_valid)
# Out:
# (10000, 12)

# %% [markdown]
# ##### *************** saving the data *****************

# %%
### setting up the respective paths to save the data
cat_cols_train_path = '../data/split_features/cat_cols_train.csv'
num_cols_train_path = '../data/split_features/num_cols_train.csv'
cat_cols_valid_path = '../data/split_features/cat_cols_valid.csv'
num_cols_valid_path = '../data/split_features/num_cols_valid.csv'

# %%
### saving them
save_data(cat_cols_train, cat_cols_train_path)
save_data(num_cols_train, num_cols_train_path)
save_data(cat_cols_valid, cat_cols_valid_path)
save_data(num_cols_valid, num_cols_valid_path)

# %%
### veryfying if everything went through
cat_cols_train = load_data(cat_cols_train_path)
cat_cols_train.head()
# Out:
#   Transaction_Type Device_Type  Location Merchant_Category   Card_Type  \
# 0   ATM Withdrawal      Tablet    London            Travel  Mastercard
# 1    Bank Transfer      Mobile  New York       Electronics        Visa
# 2   ATM Withdrawal      Tablet    Sydney       Electronics  Mastercard
# 3           Online      Mobile    London            Travel    Discover
# 4           Online      Mobile    Sydney         Groceries        Amex
#
#   Authentication_Method
# 0                   PIN
# 1                   OTP
# 2                   OTP
# 3                   PIN
# 4              Password

# %%
### check the shape
get_shape(cat_cols_train)
# Out:
# (40000, 6)

# %%
### numerical train columns
num_cols_train = load_data(num_cols_train_path)
num_cols_train.head()
# Out:
#    Transaction_Amount  Account_Balance  IP_Address_Flag  \
# 0               80.39         32068.28                0
# 1              196.60         94961.81                0
# 2               21.88         39354.55                0
# 3              121.23         46138.99                0
# 4               34.53         52750.58                0
#
#    Previous_Fraudulent_Activity  Daily_Transaction_Count  \
# 0                             0                        5
# 1                             0                        8
# 2                             0                        7
# 3                             0                        8
# 4                             0                        6
#
#    Avg_Transaction_Amount_7d  Failed_Transaction_Count_7d  Card_Age  \
# 0                     112.75                            4       142
# 1                     199.95                            1        32
# 2                     234.75                            2       203
# ...

# %%
### categorcial valid columns
cat_cols_valid = load_data(cat_cols_valid_path)
cat_cols_valid.head()
# Out:
#   Transaction_Type Device_Type  Location Merchant_Category   Card_Type  \
# 0           Online      Mobile    Sydney          Clothing  Mastercard
# 1    Bank Transfer      Mobile  New York            Travel        Amex
# 2   ATM Withdrawal      Laptop     Tokyo       Restaurants        Amex
# 3              POS      Tablet    Mumbai            Travel  Mastercard
# 4    Bank Transfer      Tablet    Sydney         Groceries        Visa
#
#   Authentication_Method
# 0                   OTP
# 1              Password
# 2              Password
# 3                   OTP
# 4             Biometric

# %%
### verify the shape
get_shape(cat_cols_valid)
# Out:
# (10000, 6)

# %%
### numerical valid columns
num_cols_valid = load_data(num_cols_valid_path)
num_cols_valid.head()
# Out:
#    Transaction_Amount  Account_Balance  IP_Address_Flag  \
# 0               19.98          1804.81                0
# 1               45.32         46648.03                0
# 2               32.25         80244.56                0
# 3               35.41         24611.99                0
# 4               57.80         27154.09                1
#
#    Previous_Fraudulent_Activity  Daily_Transaction_Count  \
# 0                             0                        2
# 1                             1                       11
# 2                             0                        7
# 3                             0                        3
# 4                             0                        1
#
#    Avg_Transaction_Amount_7d  Failed_Transaction_Count_7d  Card_Age  \
# 0                     350.41                            3       214
# 1                      47.14                            1        78
# 2                     160.14                            2        59
# ...

# %%
### check the shape
get_shape(num_cols_valid)
# Out:
# (10000, 12)
